# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv('mobileprice.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isin([0]).sum()
# Out:
# battery_power       0
# blue             1010
# clock_speed         0
# dual_sim          981
# fc                474
# four_g            957
# int_memory          0
# m_dep               0
# mobile_wt           0
# n_cores             0
# pc                101
# px_height           2
# px_width            0
# ram                 0
# sc_h                0
# sc_w              180
# talk_time           0
# three_g           477
# touch_screen      994
# wifi              986
# price_range       500
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap="RdBu",annot=True, fmt=".1f")
plt.title("Correlations Between Variables", size=15)
plt.show();

# %%
i= df[['ram', 'price_range']]
i
# Out:
#        ram  price_range
# 0     2549            1
# 1     2631            2
# 2     2603            2
# 3     2769            2
# 4     1411            1
# ...    ...          ...
# 1995   668            0
# 1996  2032            2
# 1997  3057            3
# 1998   869            0
# 1999  3919            3
#
# [2000 rows x 2 columns]

# %%
sns.pairplot(i); # i tried to see the price and ram

# %%
X = df.drop("price_range", axis=1)
y = df["price_range"]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (1400, 20)

# %%
X_test.shape
# Out:
# (600, 20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
loj_model = LogisticRegression(solver="liblinear").fit(X_train,y_train)
y_pred = loj_model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7766666666666666

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       151
#            1       0.68      0.64      0.66       146
#            2       0.63      0.55      0.59       148
#            3       0.83      0.96      0.89       155
#
#     accuracy                           0.78       600
#    macro avg       0.77      0.77      0.77       600
# weighted avg       0.77      0.78      0.77       600

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier().fit(X_train,y_train)
y_pred = knn_model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9183333333333333

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       151
#            1       0.88      0.92      0.90       146
#            2       0.89      0.86      0.87       148
#            3       0.94      0.93      0.94       155
#
#     accuracy                           0.92       600
#    macro avg       0.92      0.92      0.92       600
# weighted avg       0.92      0.92      0.92       600

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier().fit(X_train,y_train)
rf_model
y_pred = rf_model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8766666666666667

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       151
#            1       0.84      0.84      0.84       146
#            2       0.83      0.80      0.81       148
#            3       0.91      0.92      0.91       155
#
#     accuracy                           0.88       600
#    macro avg       0.88      0.88      0.88       600
# weighted avg       0.88      0.88      0.88       600

# %%
models = [
    loj_model,
    knn_model,
    rf_model,
   
]

results = []
results = pd.DataFrame(columns=["Models","Accuracy"])

for model in models:
    Name = model.__class__.__name__
    y_pred = model.predict(X_test)
    Accuracy = accuracy_score(y_test,y_pred)
    result = pd.DataFrame([[Name, Accuracy*100]], columns = ["Models","Accuracy"])
    results = results.append(result)

# %%
sns.barplot(x='Accuracy', y='Models', data=results, color = "r")
plt.xlabel('Accuracy %')
plt.title('Model Accuracy Score ');

# %%
results
# Out:
#                    Models   Accuracy
# 0      LogisticRegression  77.666667
# 0    KNeighborsClassifier  91.833333
# 0  RandomForestClassifier  87.666667

# %%
from sklearn.model_selection import cross_val_score

scores3 = cross_val_score(loj_model, X, y, cv=10)
print('Cross-Validation Accuracy Scores', scores3)
# Out:
# Cross-Validation Accuracy Scores [0.79  0.8   0.77  0.76  0.83  0.745 0.775 0.775 0.785 0.74 ]

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores3.mean(), scores3.std()))
print("Accuracy: {:.1f} %".format(scores3.mean()*100))
# Out:
# 0.78 accuracy with a standard deviation of 0.03
# Accuracy: 77.7 %

# %%
from sklearn.model_selection import cross_val_score

scores1 = cross_val_score(knn_model, X, y, cv=10)
print('Cross-Validation Accuracy Scores', scores1)
# Out:
# Cross-Validation Accuracy Scores [0.9   0.94  0.92  0.935 0.925 0.95  0.915 0.915 0.915 0.92 ]

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("Accuracy: {:.1f} %".format(scores1.mean()*100))
# Out:
# 0.92 accuracy with a standard deviation of 0.01
# Accuracy: 92.4 %

# %%
from sklearn.model_selection import cross_val_score

scores2 = cross_val_score(rf_model, X, y, cv=10)
print('Cross-Validation Accuracy Scores', scores2)
# Out:
# Cross-Validation Accuracy Scores [0.89  0.88  0.91  0.865 0.895 0.89  0.88  0.86  0.835 0.87 ]

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores2.mean(), scores2.std()))
print("Accuracy: {:.1f} %".format(scores2.mean()*100))
# Out:
# 0.88 accuracy with a standard deviation of 0.02
# Accuracy: 87.8 %

# %%
    
sco = [
    scores3,
    scores1,
    scores2,
   
]

_results = []
_results = pd.DataFrame(columns=["AccuracyCrossVal"])

for s in sco:
    Name = s
    Accuracy1 = s.mean()*100
    _result = pd.DataFrame([[Accuracy1]], columns = ["AccuracyCrossVal"])
    _results = _results.append(_result)
_results
# Out:
#    AccuracyCrossVal
# 0             77.70
# 0             92.35
# 0             87.75

# %%
results2['Models'] = results2.index

# %%
 sns.barplot(y='Accuracy', x='Models', data=results2, color = "r")
plt.xlabel('Accuracy %')
plt.title('Model Accuracy Score ');

# %%
toCompare = pd.concat([results, _results], axis=0)

# %%
import pandas as pd
data={'Models':['LogisticRegression','KNeighborsClassifier','RandomForestClassifier'],'Accuracy':[77.666667,91.833333,87.666667],'AccuracyCrossVal':[77.70,92.35,87.75]}

df1=pd.DataFrame(data)

# %%
df1
# Out:
#                    Models   Accuracy  AccuracyCrossVal
# 0      LogisticRegression  77.666667             77.70
# 1    KNeighborsClassifier  91.833333             92.35
# 2  RandomForestClassifier  87.666667             87.75

# %%
data={'Models':['LogisticRegression','LogisticRegressionCV'],'Accuracy':[77.666667,77.70]}

df2=pd.DataFrame(data)

# %%
import pandas as pd
data={'Models':['KNeighborsClassifier','KNeighborsClassifierCV'],'Accuracy':[91.833333,92.35]}

df3=pd.DataFrame(data)

# %%
import pandas as pd
data={'Models':['RandomForestClassifier','RandomForestClassifierCV'],'Accuracy':[87.666667,87.75]}

df4=pd.DataFrame(data)

# %%
sns.barplot(data=df2, x="Models", y="Accuracy")
# Out:
# <AxesSubplot:xlabel='Models', ylabel='Accuracy'>

# %%
sns.barplot(data=df3, x="Models", y="Accuracy")
# Out:
# <AxesSubplot:xlabel='Models', ylabel='Accuracy'>

# %%
sns.barplot(data=df4, x="Models", y="Accuracy")
# Out:
# <AxesSubplot:xlabel='Models', ylabel='Accuracy'>
